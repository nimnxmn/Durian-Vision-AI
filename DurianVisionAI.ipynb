# %%
# !pip install roboflow

from roboflow import Roboflow

# Read the Roboflow API key from Colab Secrets (🔑 panel ▸ add ROBOFLOW_API_KEY).
# Never hard-code API keys in a notebook that gets committed to a public repo.
from google.colab import userdata

rf = Roboflow(api_key=userdata.get("ROBOFLOW_API_KEY"))
project = rf.workspace("sriwichan").project("duriantracker")
dataset = project.version(2).download("yolov8")

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.1 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/DurianTracker-2/data.yaml epochs=100 imgsz=1024
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
